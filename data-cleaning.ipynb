# %% [markdown]
# ## Data Cleaning (Natif & NumPy)
#
# **Objectif :** Nettoyer un dataset "sale" en mélangeant les structures Python et la puissance de calcul.
#
# Tu as une liste de mesures provenant d'un capteur, mais certaines valeurs sont aberrantes ou manquantes (`None`).
#
# **À FAIRE :**
#
# 1. **Nettoyage Natif** : Utiliser une **compréhension de liste** pour créer une nouvelle liste en enlevant les valeurs `None`.
# 2. **Conversion** : Transformer cette liste nettoyée en **Array NumPy**.
# 3. **Traitement Statistique** :
#     * Les valeurs `999.0` et `-5.0` sont des erreurs. Utiliser l'indexation booléenne pour les exclure du calcul.
#     * Calculer la **médiane** des valeurs restantes.
#     * Remplacer les valeurs aberrantes par cette médiane dans le tableau NumPy.

# %%
mesures_brutes = [10.5, 12.2, None, 15.8, 999.0, 11.1, -5.0, None, 13.4]
